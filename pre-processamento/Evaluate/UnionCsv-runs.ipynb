# %%
import numpy as np
import pandas as pd
import os
import glob

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dfs = glob.glob('/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/acc/validation/*.csv')
dfs
# Out:
# ['/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/acc/validation/run-crop-baseline_validation-tag-epoch_categorical_accuracy.csv',
#  '/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/acc/validation/run-blur_validation-tag-epoch_categorical_accuracy.csv',
#  '/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/acc/validation/run-crop-baseline-mixed_validation-tag-epoch_categorical_accuracy.csv']

# %%
n_epoch = 30

df_experiments = pd.DataFrame()
for data_path in dfs:
  experiment = data_path.split('/')[-1].split('.')[0].replace('-tag-epoch_categorical_accuracy', '')
  df = pd.read_csv(data_path).head(n_epoch) 
  df['experiment'] = experiment
  df_experiments = pd.concat([df_experiments, df])

# %%
df_experiments
# Out:
#        Wall time  Step   Value                          experiment
# 0   1.649025e+09     0  0.7050        run-crop-baseline_validation
# 1   1.649025e+09     1  0.7925        run-crop-baseline_validation
# 2   1.649026e+09     2  0.7800        run-crop-baseline_validation
# 3   1.649027e+09     3  0.8050        run-crop-baseline_validation
# 4   1.649027e+09     4  0.7725        run-crop-baseline_validation
# ..           ...   ...     ...                                 ...
# 25  1.649293e+09    25  0.8075  run-crop-baseline-mixed_validation
# 26  1.649294e+09    26  0.7975  run-crop-baseline-mixed_validation
# 27  1.649295e+09    27  0.7925  run-crop-baseline-mixed_validation
# 28  1.649295e+09    28  0.8025  run-crop-baseline-mixed_validation
# 29  1.649296e+09    29  0.7800  run-crop-baseline-mixed_validation
#
# [90 rows x 4 columns]

# %%
df_experiments.experiment.value_counts()
# Out:
# run-crop-baseline_validation          30
# run-blur_validation                   30
# run-crop-baseline-mixed_validation    30
# Name: experiment, dtype: int64

# %%
#pd.pivot_table(df_experiments, index=["experiment"], values=["Value"])
stats = pd.pivot(df_experiments, index='Step', columns='experiment', values='Value')
stats
# Out:
# experiment  run-blur_validation  run-crop-baseline-mixed_validation  \
# Step
# 0                        0.5000                              0.7600
# 1                        0.5950                              0.7725
# 2                        0.7975                              0.7350
# 3                        0.8175                              0.8025
# 4                        0.8575                              0.7800
# 5                        0.8150                              0.7975
# 6                        0.8550                              0.7375
# 7                        0.8300                              0.8225
# 8                        0.8525                              0.7900
# 9                        0.8475                              0.7700
# 10                       0.8300                              0.8075
# 11                       0.8000                              0.7900
# 12                       0.8525                              0.8250
# ...

# %%
from google.colab import files
stats.to_csv('stats.csv') 
files.download("stats.csv")

# %% [markdown]
# # LOSS

# %%
dfs = glob.glob('/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/loss/validation/*.csv')
dfs
# Out:
# ['/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/loss/validation/run-crop-baseline-mixed_validation-tag-epoch_loss.csv',
#  '/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/loss/validation/run-crop-baseline_validation-tag-epoch_loss.csv',
#  '/content/drive/MyDrive/ucf_experiments/ciclo_experimental_1/pre-processamento/evaluate/loss/validation/run-blur_validation-tag-epoch_loss.csv']

# %%
n_epoch = 30

df_experiments = pd.DataFrame()
for data_path in dfs:
  experiment = data_path.split('/')[-1].split('.')[0].replace('-tag-epoch_categorical_loss', '')
  df = pd.read_csv(data_path).head(n_epoch) 
  df['experiment'] = experiment
  df_experiments = pd.concat([df_experiments, df])

# %%
stats = pd.pivot(df_experiments, index='Step', columns='experiment', values='Value')
stats
# Out:
# experiment  run-blur_validation-tag-epoch_loss  \
# Step
# 0                                     0.689565
# 1                                     0.652449
# 2                                     0.498600
# 3                                     0.464702
# 4                                     0.432966
# 5                                     0.462296
# 6                                     0.464776
# 7                                     0.412153
# 8                                     0.413902
# 9                                     0.376524
# 10                                    0.408565
# 11                                    0.441121
# 12                                    0.380052
# 13                                    0.398300
# 14                                    0.371148
# 15                                    0.356745
# 16                                    0.369576
# 17                                    0.388436
# 18                                    0.372076
# ...

# %%
from google.colab import files
stats.to_csv('stats.csv') 
files.download("stats.csv")
